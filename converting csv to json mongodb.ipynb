# %%
import pandas as pd
import numpy as np

# %%
toyota = pd.read_csv('toyota.csv')
honda = pd.read_excel('honda.xlsx')
nissan =pd.read_excel('nissan.xlsx')
mazda = pd.read_excel('mazda.xlsx')
mitsubishi = pd.read_excel('mitsubishi.xlsx')

# %%
#Installing pymongo
#!pip install pandas pymongo

# %%
#import libraries

import pymongo
import pandas as pd
import json

# %%
toyota.head(2)
# Out:
#      make fuel-type num-of-doors body-style drive-wheels  wheel-base  length  \
# 0  toyota       gas          two  hatchback          fwd        95.7   158.7
# 1  toyota       gas          two  hatchback          fwd        95.7   158.7
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   63.6    54.5         1985         ohc             four           92
# 1   63.6    54.5         2040         ohc             four           92
#
#    horsepower  peak-rpm  city-mpg  highway-mpg  price
# 0          62      4800        35           39   5348
# 1          62      4800        31           38   6338

# %%
honda.head(2)
# Out:
#     make fuel-type num-of-doors body-style drive-wheels  wheel-base  length  \
# 0  honda       gas          two  hatchback          fwd        86.6   144.6
# 1  honda       gas          two  hatchback          fwd        86.6   144.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   63.9    50.8         1713         ohc             four           92
# 1   63.9    50.8         1819         ohc             four           92
#
#    horsepower  peak-rpm  city-mpg  highway-mpg  price
# 0          58      4800        49           54   6479
# 1          76      6000        31           38   6855

# %%
#connect to mongodb
client = pymongo.MongoClient("mongodb+srv://ajupeter:Student%402023@cluster0.kdgni2u.mongodb.net/")

# %%
#create a new collection
collection_name = "toyota"

#convert dataframe to a list of dictionaries
data_list = toyota.to_dict(orient='records')

# %%
data_list
# Out:
# [{'make': 'toyota',
#   'fuel-type': 'gas',
#   'num-of-doors': 'two',
#   'body-style': 'hatchback',
#   'drive-wheels': 'fwd',
#   'wheel-base': 95.7,
#   'length': 158.7,
#   'width': 63.6,
#   'height': 54.5,
#   'curb-weight': 1985,
#   'engine-type': 'ohc',
#   'num-of-cylinders': 'four',
#   'engine-size': 92,
#   'horsepower': 62,
#   'peak-rpm': 4800,
#   'city-mpg': 35,
#   'highway-mpg': 39,
#   'price': 5348},
#  {'make': 'toyota',
#   'fuel-type': 'gas',
#   'num-of-doors': 'two',
#   'body-style': 'hatchback',
#   'drive-wheels': 'fwd',
#   'wheel-base': 95.7,
#   'length': 158.7,
#   'width': 63.6,
#   'height': 54.5,
#   'curb-weight': 2040,
#   'engine-type': 'ohc',
#   'num-of-cylinders': 'four',
#   'engine-size': 92,
#   'horsepower': 62,
#   'peak-rpm': 4800,
#   'city-mpg': 31,
#   'highway-mpg': 38,
#   'price': 6338},
#  {'make': 'toyota',
#   'fuel-type': 'gas',
#   'num-of-doors': 'four',
#   'body-style': 'hatchback',
#   'drive-wheels': 'fwd',
# ...

# %%
#creating database in mongodb
db = client["GDDA707Assessment1"]

# %%
db
# Out:
# Database(MongoClient(host=['ac-w1tpubi-shard-00-02.kdgni2u.mongodb.net:27017', 'ac-w1tpubi-shard-00-00.kdgni2u.mongodb.net:27017', 'ac-w1tpubi-shard-00-01.kdgni2u.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-oqp9gy-shard-0', tls=True), 'GDDA707Assessment1')

# %%
#insert data into mongodb
db.toyota.insert_many(data_list)
# Out:
# InsertManyResult([ObjectId('65d7d1e9f78c1f98a54d4c02'), ObjectId('65d7d1e9f78c1f98a54d4c03'), ObjectId('65d7d1e9f78c1f98a54d4c04'), ObjectId('65d7d1e9f78c1f98a54d4c05'), ObjectId('65d7d1e9f78c1f98a54d4c06'), ObjectId('65d7d1e9f78c1f98a54d4c07'), ObjectId('65d7d1e9f78c1f98a54d4c08'), ObjectId('65d7d1e9f78c1f98a54d4c09'), ObjectId('65d7d1e9f78c1f98a54d4c0a'), ObjectId('65d7d1e9f78c1f98a54d4c0b'), ObjectId('65d7d1e9f78c1f98a54d4c0c'), ObjectId('65d7d1e9f78c1f98a54d4c0d'), ObjectId('65d7d1e9f78c1f98a54d4c0e'), ObjectId('65d7d1e9f78c1f98a54d4c0f'), ObjectId('65d7d1e9f78c1f98a54d4c10'), ObjectId('65d7d1e9f78c1f98a54d4c11'), ObjectId('65d7d1e9f78c1f98a54d4c12'), ObjectId('65d7d1e9f78c1f98a54d4c13'), ObjectId('65d7d1e9f78c1f98a54d4c14'), ObjectId('65d7d1e9f78c1f98a54d4c15'), ObjectId('65d7d1e9f78c1f98a54d4c16'), ObjectId('65d7d1e9f78c1f98a54d4c17'), ObjectId('65d7d1e9f78c1f98a54d4c18'), ObjectId('65d7d1e9f78c1f98a54d4c19'), ObjectId('65d7d1e9f78c1f98a54d4c1a'), ObjectId('65d7d1e9f78c1f98a54d
# ...

# %%
#create a new collection
collection_name = "nissan"

#convert dataframe to a list of dictionaries
data_list = nissan.to_dict(orient='records')

# %%
data_list
# Out:
# [{'make': 'nissan',
#   'fuel-type': 'gas',
#   'num-of-doors': 'two',
#   'body-style': 'sedan',
#   'drive-wheels': 'fwd',
#   'wheel-base': 94.5,
#   'length': 165.3,
#   'width': 63.8,
#   'height': 54.5,
#   'curb-weight': 1889,
#   'engine-type': 'ohc',
#   'num-of-cylinders': 'four',
#   'engine-size': 97,
#   'horsepower': 69,
#   'peak-rpm': 5200,
#   'city-mpg': 31,
#   'highway-mpg': 37,
#   'price': 5499},
#  {'make': 'nissan',
#   'fuel-type': 'diesel',
#   'num-of-doors': 'two',
#   'body-style': 'sedan',
#   'drive-wheels': 'fwd',
#   'wheel-base': 94.5,
#   'length': 165.3,
#   'width': 63.8,
#   'height': 54.5,
#   'curb-weight': 2017,
#   'engine-type': 'ohc',
#   'num-of-cylinders': 'four',
#   'engine-size': 103,
#   'horsepower': 55,
#   'peak-rpm': 4800,
#   'city-mpg': 45,
#   'highway-mpg': 50,
#   'price': 7099},
#  {'make': 'nissan',
#   'fuel-type': 'gas',
#   'num-of-doors': 'two',
#   'body-style': 'sedan',
#   'drive-wheels': 'fwd',
# ...

# %%
#insert data into mongodb
db.nissan.insert_many(data_list)
# Out:
# InsertManyResult([ObjectId('65d7d1ecf78c1f98a54d4c22'), ObjectId('65d7d1ecf78c1f98a54d4c23'), ObjectId('65d7d1ecf78c1f98a54d4c24'), ObjectId('65d7d1ecf78c1f98a54d4c25'), ObjectId('65d7d1ecf78c1f98a54d4c26'), ObjectId('65d7d1ecf78c1f98a54d4c27'), ObjectId('65d7d1ecf78c1f98a54d4c28'), ObjectId('65d7d1ecf78c1f98a54d4c29'), ObjectId('65d7d1ecf78c1f98a54d4c2a'), ObjectId('65d7d1ecf78c1f98a54d4c2b'), ObjectId('65d7d1ecf78c1f98a54d4c2c'), ObjectId('65d7d1ecf78c1f98a54d4c2d'), ObjectId('65d7d1ecf78c1f98a54d4c2e'), ObjectId('65d7d1ecf78c1f98a54d4c2f'), ObjectId('65d7d1ecf78c1f98a54d4c30'), ObjectId('65d7d1ecf78c1f98a54d4c31'), ObjectId('65d7d1ecf78c1f98a54d4c32'), ObjectId('65d7d1ecf78c1f98a54d4c33')], acknowledged=True)

# %%
#create a new collection
collection_name = "honda"

#convert dataframe to a list of dictionaries
data_list = honda.to_dict(orient='records')

# %%
#insert data into mongodb
db.honda.insert_many(data_list)
# Out:
# InsertManyResult([ObjectId('65d7d1edf78c1f98a54d4c34'), ObjectId('65d7d1edf78c1f98a54d4c35'), ObjectId('65d7d1edf78c1f98a54d4c36'), ObjectId('65d7d1edf78c1f98a54d4c37'), ObjectId('65d7d1edf78c1f98a54d4c38'), ObjectId('65d7d1edf78c1f98a54d4c39'), ObjectId('65d7d1edf78c1f98a54d4c3a'), ObjectId('65d7d1edf78c1f98a54d4c3b'), ObjectId('65d7d1edf78c1f98a54d4c3c'), ObjectId('65d7d1edf78c1f98a54d4c3d'), ObjectId('65d7d1edf78c1f98a54d4c3e'), ObjectId('65d7d1edf78c1f98a54d4c3f'), ObjectId('65d7d1edf78c1f98a54d4c40')], acknowledged=True)

# %%
#create a new collection
collection_name = "mazda"

#convert dataframe to a list of dictionaries
data_list = mazda.to_dict(orient='records')

#insert data into mongodb
db.mazda.insert_many(data_list)
# Out:
# InsertManyResult([ObjectId('65d7d1eef78c1f98a54d4c41'), ObjectId('65d7d1eef78c1f98a54d4c42'), ObjectId('65d7d1eef78c1f98a54d4c43'), ObjectId('65d7d1eef78c1f98a54d4c44'), ObjectId('65d7d1eef78c1f98a54d4c45'), ObjectId('65d7d1eef78c1f98a54d4c46'), ObjectId('65d7d1eef78c1f98a54d4c47'), ObjectId('65d7d1eef78c1f98a54d4c48'), ObjectId('65d7d1eef78c1f98a54d4c49'), ObjectId('65d7d1eef78c1f98a54d4c4a'), ObjectId('65d7d1eef78c1f98a54d4c4b'), ObjectId('65d7d1eef78c1f98a54d4c4c'), ObjectId('65d7d1eef78c1f98a54d4c4d'), ObjectId('65d7d1eef78c1f98a54d4c4e'), ObjectId('65d7d1eef78c1f98a54d4c4f'), ObjectId('65d7d1eef78c1f98a54d4c50'), ObjectId('65d7d1eef78c1f98a54d4c51')], acknowledged=True)

# %%
#create new collection
collection_name = 'mitsubishi'

##convert dataframe to a list of dictionaries
data_list = mitsubishi.to_dict(orient='records')

#insert data into mongodb
db.mitsubishi.insert_many(data_list)
# Out:
# InsertManyResult([ObjectId('65d7d1eef78c1f98a54d4c52'), ObjectId('65d7d1eef78c1f98a54d4c53'), ObjectId('65d7d1eef78c1f98a54d4c54'), ObjectId('65d7d1eef78c1f98a54d4c55'), ObjectId('65d7d1eef78c1f98a54d4c56'), ObjectId('65d7d1eef78c1f98a54d4c57'), ObjectId('65d7d1eef78c1f98a54d4c58'), ObjectId('65d7d1eef78c1f98a54d4c59'), ObjectId('65d7d1eef78c1f98a54d4c5a'), ObjectId('65d7d1eef78c1f98a54d4c5b'), ObjectId('65d7d1eef78c1f98a54d4c5c'), ObjectId('65d7d1eef78c1f98a54d4c5d'), ObjectId('65d7d1eef78c1f98a54d4c5e')], acknowledged=True)
